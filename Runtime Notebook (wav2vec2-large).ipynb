# %%
from classifier import generate_embeddings, classify_phonation_mode, k_fold_cross_val, svm_hyperparameter_tuning
import pandas as pd
import warnings
warnings.filterwarnings("ignore") # suppress all warnings

# %%
generate_embeddings("data", "wav2vec2large")
# Out:
# Processing WAV files:   0%|                             | 0/762 [00:00<?, ?it/s]Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
# Generating embeddings layer-wise: 100%|█████████| 25/25 [00:17<00:00,  1.45it/s]

# %%
wav2vec2large_df = classify_phonation_mode("wav2vec2large")
wav2vec2large_df.to_csv('results/wav2vec2large_df.csv', index=False)
# Out:
# Layer-wise classification: 100%|████████████████| 25/25 [09:24<00:00, 22.56s/it]

# %% [markdown]
# ## Stratified K-Fold Cross Validation

# %%
wav2vec2large_5fold_df = k_fold_cross_val("wav2vec2large")
wav2vec2large_5fold_df.to_csv('results/wav2vec2large_5fold_df.csv', index=False)
# Out:
# Layer-wise classification: 100%|███████████████| 25/25 [44:47<00:00, 107.49s/it]

# %% [markdown]
# ## Hyper-parameter Tuning

# %%
model_name = "wav2vec2large"
layer=1
param_grid = {
    'C': [0.001, 0.01, 0.1],
    'gamma': [0.00001, 0.000001, 0.00001, 0.0001, 0.0001, 0.001, 'scale'],
}

# Perform hyperparameter tuning
best_params, best_score = svm_hyperparameter_tuning(model_name, layer, param_grid)

print("Best hyperparameters:", best_params)
print("Best cross-validation score:", best_score)
# Out:
# Best hyperparameters: {'C': 0.001, 'gamma': 1e-05}
# Best cross-validation score: 0.9343825249398006
