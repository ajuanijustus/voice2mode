# %%
from classifier import classify_wav, k_fold_cross_val, svm_hyperparameter_tuning
import pandas as pd
import warnings
warnings.filterwarnings("ignore") # suppress all warnings

# %%
# data_directory = "unit_test_data"
data_directory = "data"
model_name = "wav2vec2large"

wav2vec2large_df = classify_wav(data_directory, model_name)
wav2vec2large_df.to_csv('wav2vec2large_df.csv', index=False)
# Out:
# Processing WAV files:   0%|                             | 0/762 [00:00<?, ?it/s]Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
# Layer-wise classification:   4%|▋                | 1/25 [00:21<08:32, 21.37s/it]
# Accuracy for Layer 0: 0.9215686274509803
# Layer-wise classification:   8%|█▎               | 2/25 [00:43<08:21, 21.80s/it]
# Accuracy for Layer 1: 0.9150326797385621
# Layer-wise classification:  12%|██               | 3/25 [01:05<08:04, 22.01s/it]
# Accuracy for Layer 2: 0.9215686274509803
# Layer-wise classification:  16%|██▋              | 4/25 [01:28<07:49, 22.36s/it]
# Accuracy for Layer 3: 0.9019607843137255
# Layer-wise classification:  20%|███▍             | 5/25 [01:50<07:26, 22.35s/it]
# Accuracy for Layer 4: 0.9150326797385621
# ...

# %% [markdown]
# ## 5-fold cross validation

# %%
# data_directory = "unit_test_data"
data_directory = "data"
model_name = "wav2vec2large"

wav2vec2large_5fold_df = k_fold_cross_val(data_directory, model_name)
wav2vec2large_5fold_df.to_csv('wav2vec2large_5fold_df.csv', index=False)
# Out:
# ...
# Layer-wise Cross-validation:   4%|▌             | 1/25 [01:43<41:14, 103.11s/it]
# Average accuracy for Layer 0: 0.9252063983488131
# Layer-wise Cross-validation:   8%|█             | 2/25 [03:30<40:26, 105.49s/it]
# Average accuracy for Layer 1: 0.9343825249398006
# Layer-wise Cross-validation:  12%|█▍          | 3/25 [07:52<1:04:57, 177.17s/it]
# Average accuracy for Layer 2: 0.9330667354661163
# Layer-wise Cross-validation:  16%|█▉          | 4/25 [11:20<1:06:18, 189.44s/it]
# Average accuracy for Layer 3: 0.930452356381149
# Layer-wise Cross-validation:  20%|██▊           | 5/25 [13:15<54:08, 162.41s/it]
# Average accuracy for Layer 4: 0.9265049879600964
# Layer-wise Cross-validation:  24%|███▎          | 6/25 [15:05<45:47, 144.58s/it]
# Average accuracy for Layer 5: 0.9252149982800137
# Layer-wise Cross-validation:  28%|███▉          | 7/25 [16:52<39:40, 132.27s/it]
# Average accuracy for Layer 6: 0.9238992088063295
# ...

# %% [markdown]
# ## Finalaise layer for each of the 3 to hyperparam tune?

# %%
# data_directory = "unit_test_data"
data_directory = "data"
model_name = "wav2vec2large"
layer=1
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': [0.001, 0.01, 0.1, 1],
}

# Perform hyperparameter tuning
best_params, best_score = svm_hyperparameter_tuning(data_directory, model_name, layer, param_grid)

print("Best hyperparameters:", best_params)
print("Best cross-validation score:", best_score)
# Out:
# Processing WAV files:   0%|                             | 0/762 [00:00<?, ?it/s]Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Processing WAV files: 100%|███████████████████| 762/762 [03:08<00:00,  4.03it/s]
# Best hyperparameters: {'C': 0.1, 'gamma': 0.001}
# Best cross-validation score: 0.9343825249398006

# %% [markdown]
# ## 5-fold CV for hyper param tuned models
